# %% [markdown]
# ## Daedalus Conductivity Estimations Based on Empirical Models
#
# ### Table of Contents
#
# ### Theoretical Description
#
# #### Introduction
#
# Pedersen conductivity (σ_P) is required in Joule heating calculations, but are also extremely important in ionospheric and magnetospheric modelling. Pedersen conductivity cannot be obtained by direct measurement, as it depends on a large number of terms, such as composition of different ion species (in number densities N_i) and the various collision rates between ion species and neutral species. These, in turn, depend on the ion and electron temperatures (T_i and T_n), the neutral densities of the neutral species (N_n), and the ion species. In calculations of the Pedersen conductivity, the ratio (r_i) of each species’ collision rate versus its gyrofrequency needs to be estimated. The collision rate will depend on the species’ density, thus neutral composition needs to be measured independently through mass spectrometry.
#
# #### Conductivity estimation methodology
#
# The Pedersen conductivity, σ_P can be calculated as:
#
# $$  \sigma_{P} = \frac{q_{e}}{B} [ N_{O^{+}} \frac{\kappa_{O^{+}}}{ 1 + \kappa_{O^{+}}^{2}} +
# 										   N_{O_{2}^{+}} \frac{\kappa_{O_{2}^{+}}}{ 1 + \kappa_{O_{2}^{+}}^{2}} +
# 										   N_{NO^{+}} \frac{\kappa_{NO^{+}}}{ 1 + \kappa_{NO^{+}}^{2}} +
# 										   N_{e} \frac{\kappa_{e}}{ 1 + \kappa_{e}^{2}}
# 										 ] $$
#
# Where $$\kappa_{j} = \frac{\Omega_{j}}{v_{j}}$$ is the cyclotron to collision frequency ratio with the subscript $j$ denoting electrons ($j=e$) or ions ($j=i$), $q_{e}$ is the elementary electric charge ($1.602176634 \times 10^{-19} C $) and $N_{j}$ denotes the electron ($j=e$) or ion ($j=i$) density (in $cm^{-3}$).
#
#
# The collision rates depend on a number of terms, such as: on the density and composition of the ion and neutral species, which need to be measured independently through mass spectrometry; on the ion and electron temperatures; and on the values for collision cross sections. The latter are calculated primarily through laboratory experiments of ion-neutral collisions. However, these may have systematic uncertainties in the upper atmosphere, and their accuracy has never been evaluated in-situ. These measurements, through the comparison of the two methodologies described above, will also allow a new estimate of collisional cross sections, which are needed and widely used in simulations, analysis of radar data etc. An overview of the various parameters used in conductivity calculations is given in the following tables:
#
# Table D1.3: Overview of the parameters used in conductivity calculations.
# $$r_i=v_i/Ω_i$$
# $$r_e=v_e/Ω_e$$
# $$Ω_i=eB/m_i$$
# $$Ω_e=eB/m_e$$
#
# $$v_(O_2^+ )=v_(O_2^+-O_2 )+v_(O_2^+-O)+v_(O_2^+-N_2 )$$
#
# $$v_(O^+ )=v_(O^+-O_2 )+v_(O^+-O)+v_(O^+-N_2 )$$
#
# $$v_(NO^+ )=v_(NO^+-O_2 )+v_(NO^+-O)+v_(NO^+-N_2)$$
#
# $$v_e=2.33×10^-11 N_(N_2 ) T_e (1-1.21×10^(-4) T_e )+1.82×10^(-10) N_(O_2 ) √(T_e ) (1+3.6×10^(-2) √(T_e ))+      8.9×10^(-11) N_O √(T_e ) (1+5.7×10^(-4) T_e )$$
#
# $$v_(O_2^+-O_2 )=N_(O_2 ) 2.59×〖10〗^(-11) √(T_r ) [1-0.073 log_10⁡〖T_r 〗 ]^2$$ ,
# where $$T_r=(T_i+T_n)/2$$
# (T_r>800K)
#
# v_(O_2^+-O)=N_O 2.31×〖10〗^10
# v_(O_2^+-N_2 )=N_(N_2 ) 4.13×〖10〗^10
# v_(O^+-O_2 )=N_(O_2 ) 6.64×〖10〗^10
# v_(O^+-O)=N_O 3.67×〖10〗^(-11) √(T_r ) [1-0.064 log_10⁡〖T_r 〗 ]^2 , where T_r=(T_i+T_n)/2
# (T_r>235K)
#
# v_(O^+-N_2 )=N_(N_2 ) 6.82×〖10〗^10
# v_(NO^+-O_2 )=N_(O_2 ) 4.27×〖10〗^10
# v_(NO^+-O)=N_O 2.44×〖10〗^10
# v_(NO^+-N_2 )=N_(N_2 ) 4.39×〖10〗^10
#
#
# So, if we want to evaluate every parameter that goes into a Joule heating calculation in a local volume of space, the geophysical observables required are total density, the neutral winds, the ion drifts, the ion density, ion temperature, electron temperature, ion composition, the total neutral composition which is a separate measurement that can be used as a check, the magnetic field and the DC electric fields.
# In the system of the neutral atmosphere, Joule heating and conductivity will be estimated by Eq. (4) and (5) listed above. The error of both quantities can be computed by error propagation formula, applied first to Eq. (5), to derive the error in conductivity, and then to Eq. (4), to derive the error in Joule heating. The error in the higher level, L3, products depend on the individual errors of the observed quantities, L2 products (δE, δvn, δB, the constituents of δσ), to be provided by instrument teams (WP2.1, WP3.4) in relation to state of the art resolution and accuracy (WP1.1), consolidated product requirements (WP1.4), and performance metrics (WP3.4).
#
# #### Modeling of Conductivity estimates
#
# As part of the sensitivity analysis in this study, the above parameters for Joule heating and for conductivity are be calculated using different LTI models. In the following, IRI-16 gives the electron density, electron temperature, ion temperature and ion composition. NRLMSISE-00 gives the neutral temperature and neutral composition density.
#
# Below these models and the corresponding variables that are outputs of these models are listed, with variables that are involved in Joule Heating and Conductivity calculations marked in blue:
#
# •	IRI-16 (Ne, Te, Ti, H+, He+, O+, O2+, NO+, TEC, F1 and spread-F probability)
# •	NRLMSISE-00 (Tn, He, O, O2, N2, Ar, H, N, Density, collision frequency)
#
#
# Below we plot the inputs that go into the Conductivity Estimations.
#
# Densities: (units in: ...)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# Below we plot the Pedersen Conductivity based on:
#
#
#
# (units of Pedersen Conductivity in: ...)

# %% [markdown]
# #### Error Analysis for Conductivity estimates
#
#
# 		\begin{split}
# 		\dd{\sigma_{P}}^{2} = \ \mid \pdv{\sigma_{P}}{B}\mid ^{2} .\dd{B}^{2} +
# 								\mid \pdv{\sigma_{P}}{N_{O^{+}}}\mid ^{2} .\dd{N_{O^{+}}}^{2} +
# 								\mid \pdv{\sigma_{P}}{\kappa_{O^{+}}}\mid ^{2} .\dd{\kappa_{O^{+}}}^{2}  \\
# 							+	\mid \pdv{\sigma_{P}}{N_{O_{2}^{+}}}\mid ^{2} .\dd{N_{O_{2}^{+}}}^{2} +
# 								\mid \pdv{\sigma_{P}}{\kappa_{O_{2}^{+}}}\mid ^{2} .\dd{\kappa_{O_{2}^{+}}}^{2} +
# 								\mid \pdv{\sigma_{P}}{N_{NO^{+}}}\mid ^{2} .\dd{N_{NO^{+}}}^{2}  \\
# 							+	\mid \pdv{\sigma_{P}}{\kappa_{NO^{+}}}\mid ^{2} .\dd{\kappa_{NO^{+}}}^{2} +
# 								\mid \pdv{\sigma_{P}}{N_{e}}\mid ^{2} .\dd{N_{e}}^{2} +
# 								\mid \pdv{\sigma_{P}}{\kappa_{e}}\mid ^{2} .\dd{\kappa_{e}}^{2}
# 		\end{split}
# 	\end{equation}
#
# 	\vspace{1cm}
# 	\begin{itemize}
# 		\item $ \mid \pdv{\sigma_{P}}{B} \mid ^{2} \ = (\frac{q_{e}}{B^{2}})^{2} [ N_{O^{+}} \frac{\kappa_{O^{+}}}{ 1 + \kappa_{O^{+}}^{2}} +
# 		N_{O_{2}^{+}} \frac{\kappa_{O_{2}^{+}}}{ 1 + \kappa_{O_{2}^{+}}^{2}} +
# 		N_{NO^{+}} \frac{\kappa_{NO^{+}}}{ 1 + \kappa_{NO^{+}}^{2}} +
# 		N_{e} \frac{\kappa_{e}}{ 1 + \kappa_{e}^{2}}
# 		] ^{2} $
#
# 		\item $ \mid \pdv{\sigma_{P}}{N_{O^{+}}} \mid ^{2} \ = (\frac{q_{e}}{B})^{2} (\frac{\kappa_{O^{+}}}{1+\kappa_{O^{+}}^{2}})^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{N_{O_{2}^{+}}} \mid ^{2} \ = (\frac{q_{e}}{B})^{2} (\frac{\kappa_{O_{2}^{+}}}{1+\kappa_{O_{2}^{+}}^{2}})^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{N_{NO^{+}}} \mid ^{2} \ = (\frac{q_{e}}{B})^{2} (\frac{\kappa_{NO^{+}}}{1+\kappa_{NO^{+}}^{2}})^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{N_{e}} \mid ^{2} \ = (\frac{q_{e}}{B})^{2} (\frac{\kappa_{e}}{1+\kappa_{e}^{2}})^{2} $
#
# 		\item $ \mid \pdv{\sigma_{P}}{\kappa_{O^{+}}} \mid ^{2} \ = (\frac{q_{e} N_{O^{+}}}{B})^{2} [\frac{1 - \kappa_{O^{+}}^{2}}{(1 + \kappa_{O^{+}}^{2})^{2}}]^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{\kappa_{O_{2}^{+}}} \mid ^{2} \ = (\frac{q_{e} N_{O_{2}^{+}}}{B})^{2} [\frac{1 - \kappa_{O_{2}^{+}}^{2}}{(1 + \kappa_{O_{2}^{+}}^{2})^{2}}]^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{\kappa_{NO^{+}}} \mid ^{2} \ = (\frac{q_{e} N_{NO^{+}}}{B})^{2} [\frac{1 - \kappa_{NO^{+}}^{2}}{(1 + \kappa_{NO^{+}}^{2})^{2}}]^{2} $
# 		\item $ \mid \pdv{\sigma_{P}}{\kappa_{e}} \mid ^{2} \ = (\frac{q_{e} N_{e}}{B})^{2} [\frac{1 - \kappa_{e}^{2}}{(1 + \kappa_{e}^{2})^{2}}]^{2} $
#
# 	\end{itemize}
#
#
# 		\vspace{1cm}
# 	$
# 	\rightarrow \dd{\kappa_{O^{+}}}^{2} = \mid \pdv{\kappa_{O^{+}}}{\Omega_{O^{+}}} \mid ^{2} .\dd{\Omega_{O^{+}}}^{2} + \mid \pdv{\kappa_{O^{+}}}{v_{O^{+}}} \mid ^{2} .\dd{v_{O_{^{+}}}}^{2}
# 	$
#
# 	$
# 	\rightarrow \dd{\kappa_{O_{2}^{+}}}^{2} = \mid \pdv{\kappa_{O_{2}^{+}}}{\Omega_{O_{2}^{+}}} \mid ^{2} .\dd{\Omega_{O_{2}^{+}}}^{2} + \mid \pdv{\kappa_{O_{2}^{+}}}{v_{O_{2}^{+}}} \mid ^{2} .\dd{v_{O_{2}^{+}}}^{2}
# 	$
#
# 	$
# 	\rightarrow \dd{\kappa_{NO^{+}}}^{2} = \mid \pdv{\kappa_{NO^{+}}}{\Omega_{NO^{+}}} \mid ^{2} .\dd{\Omega_{NO^{+}}}^{2} + \mid \pdv{\kappa_{NO^{+}}}{v_{NO^{+}}} \mid ^{2} .\dd{v_{NO_{^{+}}}}^{2}
# 	$
#
# 	$
# 	\rightarrow \dd{\kappa_{e}^{2} = \mid \pdv{\kappa_{e}}{\Omega_{e}} \mid ^{2} .\dd{\Omega_{e}}^{2} + \mid \pdv{\kappa_{e}}{v_{e}} \mid ^{2} .\dd{v_{e}}}^{2}
# 	$
#
# 				\vspace{1cm}
# 	The cyclotron frequency $\Omega_{j}=\frac{q_{e}B}{m_{j}}$(in $s^{-1}$), where $m_{j}$ is the mass of electron($j=e$) or ion($j=i$).Thus:
#
# 	$
# 		\dagger \dd{\Omega_{O^{+}}}^{2} = \mid \pdv{\Omega_{O^{+}}}{B} \mid ^{2} .\dd{B^{2}} = (\frac{q_{e}}{m_{O^{+}}})^{2}
# 	$
#
# 	$
# 	\dagger \dd{\Omega_{O_{2}^{+}}}^{2} = \mid \pdv{\Omega_{O_{2}^{+}}}{B} \mid ^{2} .\dd{B^{2}} = (\frac{q_{e}}{m_{O_{2}^{+}}})^{2}
# 	$
#
#
# 	$
# 	\dagger \dd{\Omega_{NO^{+}}}^{2} = \mid \pdv{\Omega_{NO^{+}}}{B} \mid ^{2} .\dd{B^{2}} = (\frac{q_{e}}{m_{NO^{+}}})^{2}
# 	$
#
# 	$
# 	\dagger \dd{\Omega_{e}}^{2} = \mid \pdv{\Omega_{e}}{B} \mid ^{2} .\dd{B^{2}} = (\frac{q_{e}}{m_{e}})^{2}
# 	$
#
# 	\vspace{1cm}
#
# 	$
# 	\blacktriangleright		v_{O^{+}} = v_{O^{+}-O} + v_{O^{+}-O_{2}} + v_{O^{+}-N_{2}} + v_{O^{+}-e}
# 									+ v_{O^{+}-O^{+}} + v_{O^{+}-O_{2}^{+}} + v_{O^{+}-NO^{+}}
# 	$
#
# 	$
# 	\blacktriangleright		v_{O_{2}^{+}} = v_{O_{2}^{+}-O_{2}} + v_{O_{2}^{+}-O} + v_{O_{2}^{+}-N_{2}}
# 	                           + v_{O_{2}^{+}-e}+ v_{O_{2}^{+}-O_{2}^{+}} + v_{O_{2}^{+}-O^{+}} + v_{O_{2}^{+}-NO^{+}}
# 	$
#
# 	$
# 	\blacktriangleright		v_{NO^{+}} = v_{NO^{+}-O} + v_{NO^{+}-O_{2}} + v_{O^{+}-N_{2}} + v_{NO^{+}-e}
# 										+ v_{NO^{+}-NO^{+}} + \\
# 										 + v_{NO^{+}-O^{+}} + v_{NO^{+}-O_{2}^{+}}
# 	$
#
# 	$
# 	\blacktriangleright		v_{e} = v_{e-e} + v_{e-O} + v_{e-O_{2}} + v_{e-N_{2}}
# 	$
#
# 		\vspace{0.5cm}
# 	Where $v_{j}$ is the collision frequency(in $s^{-1}$) for each kind of ions and for electrons.
#
# 	\vspace{1cm}
#
# 	\begin{equation*}
# 		\begin{split}
# 		  \boxed{ \textbf{ 1) } \dd{v_{O^{+}}}^{2} = \dd{v_{O^{+}-O}}^{2} + \dd{v_{O^{+}-O_{2}}}^{2} +\dd{v_{O^{+}-N_{2}}}^{2} + \dd{v_{O^{+}-e}}^{2} + \dd{v_{O^{+}-O^{+}}}^{2} + } \\
# 		  \boxed{ + \dd{v_{O^{+}-O_{2}^{+}}}^{2} + \dd{v_{O^{+}-NO^{+}}}^{2} }
# 		\end{split}
# 	\end{equation*}
#
# 			\vspace{1cm}
# 		$
# 			\dagger v_{O^{+}-O} = 3.67 \times 10^{-11} N_{O} T_{r}^{1/2} (1-0.064log_{10}T_{r})^{2}
# 		$
#
# 		\vspace{0.5cm}
# 	Where $T_{r} = \frac{T_{i}+T_{n}}{2}$(for $T_{r}>235K$),$T_{i}$ is the average ion temperature(in kelvin) and $T_{n}$ is the neutral average temperature(in kelvin).
# 	\\
#
# 	$
# 	\dagger v_{O^{+}-O_{2}} = 6.64 \times 10^{10} N_{O_{2}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O^{+}-N_{2}} = 6.82 \times 10^{10} N_{N_{2}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O^{+}-e} = \frac{54.5 N_{O^{+}} Z_{O^{+}}^{2}}{T_{e}^{3/2}}
# 	$
#
# 	\vspace{0.5cm}
# 	Where $Z_{i}$ is the atomic number for each ion.
# 	 \vspace{0.4cm}
#
#
# 	$
# 	\dagger v_{O^{+}-O^{+}} = \frac{0.22 N_{O^{+}}}{T_{O^{+}}^{3/2}}
# 	$
#
# 		\vspace{0.3cm}
# 	$
# 	\dagger v_{O^{+}-O_{2}^{+}} = \frac{0.26 N_{O_{2}^{+}}}{T_{O_{2}^{+}}^{3/2}}
# 	$
#
# 	   \vspace{0.3cm}
# 	$
# 	\dagger v_{O^{+}-NO^{+}} = \frac{0.26 N_{NO^{+}}}{T_{NO^{+}}^{3/2}}
# 	$
#
# 	\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-O}}^{2} = \mid \pdv{v_{O^{+}-O}}{N_{O}} \mid ^{2} .\dd{N_{O}}^{2} + \mid \pdv{v_{O^{+}-O}}{T_{O}} \mid ^{2}
# 	.\dd{T_{O}}^{2} + \mid \pdv{v_{O^{+}-O}}{T_{O^{+}}} \mid ^{2} .\dd{T_{O^{+}}}^{2}
# 	$
#
# 	\vspace{0.5cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O}}{N_{O}} \mid ^{2} = [3.67 \times 10^{-11}(1-0.064log_{10}T_{r})^{2}]^{2}T_{r}
# 	$
#
# 	\begin{equation*}
# 		\begin{split}
# \ \ \ 	\rightarrow \mid \pdv{v_{O^{+}-O}}{T_{O}} \mid ^{2} = [1.15328 \times 10^{-11}-6.81202 \times 10^{-13}log_{10}(0.5(T_{O^{+}}+T_{O})) \\
# 		+ 1.00242 \times 10^{-14}log_{10}(0.5(T_{O^{+}}+T_{O}))^{2}]^{2}\dfrac{N_{O}^{2}}{T_{O^{+}}+T_{O}}
# 		\end{split}
# 	\end{equation*}
#
# 		\begin{equation*}
# 	\begin{split}
# 	\ \ \ 	\rightarrow \mid \pdv{v_{O^{+}-O}}{T_{O^{+}}} \mid ^{2} = [1.15328 \times 10^{-11}-6.81202 \times 10^{-13}log_{10}(0.5(T_{O^{+}}+T_{O})) \\
# 	+ 1.00242 \times 10^{-14}log_{10}(0.5(T_{O^{+}}+T_{O}))^{2}]^{2}\dfrac{N_{O}^{2}}{T_{O^{+}}+T_{O}}
# 	\end{split}
# 	\end{equation*}
#
# 		\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-O_{2}}}^{2} = \mid \pdv{v_{O^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} .\dd{N_{O_{2}}}^{2}
# 	$
#
# 		\vspace{0.5cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} = (6.64 \times 10^{10})^{2}
# 	$
#
# 		\vspace{0.5cm}
#
# 	$
# 	\bullet \dd{v_{O^{+}-N_{2}}}^{2} = \mid \pdv{v_{O^{+}-N_{2}}}{N_{N_{2}}} \mid ^{2} .\dd{N_{N_{2}}}^{2}
# 	$
#
# 	\vspace{0.5cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O_{2}}}{N_{N_{2}}} \mid ^{2} = (6.82 \times 10^{10})^{2}
# 	$
#
# 		\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-e}}^{2} = \mid \pdv{v_{O^{+}-e}}{N_{O^{+}}} \mid ^{2} .\dd{N_{O^{+}}}^{2} +
# 									\mid \pdv{v_{O^{+}-e}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 	$
#
# 	\vspace{0.5cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-e}}{N_{O^{+}}} \mid ^{2} = \frac{(54.5 Z_{O^{+}}^{2})^{2}}{T_{e}^{3}}
# 	$
#
# 		\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-e}}{T_{e}} \mid ^{2} = \frac{(81.75 N_{O^{+}} Z_{O^{+}}^{2})^{2}}{T_{e}^{5}}
# 	$
#
# 		\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-O^{+}}}^{2} = \mid \pdv{v_{O^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} .\dd{N_{O^{+}}}^{2} +
# 	\mid \pdv{v_{O^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} .\dd{T_{O^{+}}}^{2}
# 	$
#
# 		\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} = \frac{0.22^{2}}{T_{O^{+}}^{3}}
# 	$
#
# 		\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} = \frac{(0.33N_{O^{+}})^{2}}{T_{O^{+}}^{5}}
# 	$
#
# 		\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-O_{2}^{+}}}^{2} = \mid \pdv{v_{O^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} .\dd{N_{O_{2}^{+}}}^{2} +
# 	\mid \pdv{v_{O^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} .\dd{T_{O_{2}^{+}}}^{2}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} = \frac{0.26^{2}}{T_{O_{2}^{+}}^{3}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} = \frac{(0.39N_{O_{2}^{+}})^{2}}{T_{O_{2}^{+}}^{5}}
# 	$
#
# 		\vspace{0.5cm}
# 	$
# 	\bullet \dd{v_{O^{+}-NO^{+}}}^{2} = \mid \pdv{v_{O^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} .\dd{N_{NO^{+}}}^{2} +
# 	\mid \pdv{v_{O^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} .\dd{T_{NO^{+}}}^{2}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} = \frac{0.26^{2}}{T_{NO^{+}}^{3}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} = \frac{(0.39N_{NO^{+}})^{2}}{T_{NO^{+}}^{5}}
# 	$
#
# 			\vspace{1cm}
#
# 		\begin{equation*}
# 			\begin{split}
# 		 \boxed{ \textbf{ 2) } \dd{v_{O_{2}^{+}}}^{2} = \dd{v_{O_{2}^{+}-O_{2}}}^{2} + \dd{v_{O_{2}^{+}-O}}^{2} + \dd{v_{O_{2}^{+}-N_{2}}}^{2}
# 		+ \dd{v_{O_{2}^{+}-e}}^{2} + \dd{v_{O_{2}^{+}-O_{2}^{+}}}^{2} + \dd{v_{O_{2}^{+}-O^{+}}}^{2} + } \\
# 	\boxed{ + \dd{v_{O_{2}^{+}-NO^{+}}}^{2} }
# 		   \end{split}
# 		\end{equation*}
#
# 				\vspace{1cm}
# 	$
# 	\dagger v_{O_{2}^{+}-O_{2}} = 2.59 \times 10^{-11} N_{O_{2}} T_{r}^{1/2} (1-0.073log_{10}T_{r})^{2}
# 	$
#
# 	\vspace{0.3cm}
# 	Where $T_{r} = \frac{T_{i}+T_{n}}{2}$(for $T_{r}>800K$),$T_{i}$ is the average ion temperature(in kelvin) and $T_{n}$ is the neutral average temperature(in kelvin).
#
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O_{2}^{+}-O} = 2.31 \times 10^{10} N_{O}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O_{2}^{+}-N_{2}} = 4.13 \times 10^{10} N_{N_{2}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O_{2}^{+}-e} = \frac{54.5 N_{O_{2}^{+}} Z_{O_{2}^{+}}^{2}}{T_{e}^{3/2}}
# 	$
#
# 	\vspace{0.3cm}
# 	Where $Z_{i}$ is the atomic number for each ion.
#
# 	\vspace{0.4cm}
# 	$
# 	\dagger v_{O_{2}^{+}-O_{2}^{+}} = \frac{0.16 N_{O_{2}^{+}}}{T_{O_{2}^{+}}^{3/2}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O_{2}^{+}-O^{+}} = \frac{0.13 N_{O^{+}}}{T_{O^{+}}^{3/2}}
# 	$
#
# 	\vspace{0.3cm}
# 	$
# 	\dagger v_{O_{2}^{+}-NO^{+}} = \frac{0.16 N_{NO^{+}}}{T_{NO^{+}}^{3/2}}
# 	$
#
# 		\vspace{0.5cm}
#
# 		\small
# 	\begin{equation*}
# 	\bullet \dd{v_{O_{2}^{+}-O_{2}}}^{2} = \mid \pdv{v_{O_{2}^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} .\dd{N_{O_{2}}}^{2} + \mid \pdv{v_{O_{2}^{+}-O_{2}}}{T_{O_{2}^{+}}} \mid ^{2}
# 	.\dd{T_{O_{2}^{+}}}^{2} + \mid \pdv{v_{O_{2}^{+}-O_{2}}}{T_{O_{2}}} \mid ^{2} .\dd{T_{O_{2}}}^{2}
# 	\end{equation*}
#
# 	\normalsize
#
# 	\vspace{0.5cm}
# 	$
# 	\rightarrow \mid \pdv{v_{O_{2}^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} = [2.56 \times 10^{-11}(1-0.073log_{10}T_{r})^{2}]^{2}T_{r}
# 	$
#
# 	\begin{equation*}
# 	\begin{split}
# 	\ \ \ 	\rightarrow \mid \pdv{v_{O_{2}^{+}-O_{2}}}{T_{O_{2}^{+}}} \mid ^{2} = [7.99579 \times 10^{-12}-5.43805 \times 10^{-13}log_{10}(0.5(T_{O_{2}^{+}}+T_{O_{2}})) \\
# 	+ 9.20384 \times 10^{-15}log_{10}(0.5(T_{O_{2}^{+}}+T_{O_{2}}))^{2}]^{2}\dfrac{N_{O_{2}}^{2}}{T_{O_{2}^{+}}+T_{O_{2}}}
# 	\end{split}
# 	\end{equation*}
#
# 	\begin{equation*}
# 	\begin{split}
# 	\ \ \ 	\rightarrow \mid \pdv{v_{O_{2}^{+}-O_{2}}}{T_{O_{2}}} \mid ^{2} = [7.99579 \times 10^{-12}-5.43805 \times 10^{-13}log_{10}(0.5(T_{O_{2}^{+}}+T_{O_{2}})) \\
# 	+ 9.20384 \times 10^{-15}log_{10}(0.5(T_{O_{2}^{+}}+T_{O_{2}}))^{2}]^{2}\dfrac{N_{O_{2}}^{2}}{T_{O_{2}^{+}}+T_{O_{2}}}
# 	\end{split}
# 	\end{equation*}
#
# 			\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{O_{2}^{+}-O}}^{2} = \mid \pdv{v_{O_{2}^{+}-O}}{N_{O}} \mid ^{2} .\dd{N_{O}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-O}}{N_{O}} \mid ^{2} = (2.31 \times 10^{10})^{2}
# 		$
#
# 				\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{O_{2}^{+}-N_{2}}}^{2} = \mid \pdv{v_{O_{2}^{+}-N_{2}}}{N_{N_{2}}} \mid ^{2} .\dd{N_{N_{2}}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-N_{2}}}{N_{N_{2}}} \mid ^{2} = (4.13 \times 10^{10})^{2}
# 		$
#
# 				\vspace{0.5cm}
# 			$
# 			\bullet \dd{v_{O_{2}^{+}-e}}^{2} = \mid \pdv{v_{O_{2}^{+}-e}}{N_{O_{2}^{+}}} \mid ^{2} .\dd{N_{O_{2}^{+}}}^{2} +
# 			\mid \pdv{v_{O_{2}^{+}-e}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 			$
#
# 			\vspace{0.5cm}
# 			$
# 			\rightarrow \mid \pdv{v_{O_{2}^{+}-e}}{N_{O_{2}^{+}}} \mid ^{2} = \frac{(54.5 Z_{O_{2}^{+}}^{2})^{2}}{T_{e}^{3}}
# 			$
#
# 			\vspace{0.3cm}
# 			$
# 			\rightarrow \mid \pdv{v_{O_{2}^{+}-e}}{T_{e}} \mid ^{2} = \frac{(81.75 N_{O_{2}^{+}} Z_{O_{2}^{+}}^{2})^{2}}{T_{e}^{5}}
# 			$
#
#
#
# 			\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{O_{2}^{+}-O_{2}^{+}}}^{2} = \mid \pdv{v_{O_{2}^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} .\dd{N_{O_{2}^{+}}}^{2} +
# 		\mid \pdv{v_{O_{2}^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} .\dd{T_{O_{2}^{+}}}^{2}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} = \frac{0.16^{2}}{T_{O_{2}^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} = \frac{(0.24N_{O_{2}^{+}})^{2}}{T_{O_{2}^{+}}^{5}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{O_{2}^{+}-O^{+}}}^{2} = \mid \pdv{v_{O_{2}^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} .\dd{N_{O^{+}}}^{2} +
# 		\mid \pdv{v_{O_{2}^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} .\dd{T_{O^{+}}}^{2}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} = \frac{0.13^{2}}{T_{O^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} = \frac{(0.195N_{O^{+}})^{2}}{T_{O^{+}}^{5}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{O_{2}^{+}-NO^{+}}}^{2} = \mid \pdv{v_{O_{2}^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} .\dd{N_{NO^{+}}}^{2} +
# 		\mid \pdv{v_{O_{2}^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} .\dd{T_{NO^{+}}}^{2}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} = \frac{0.16^{2}}{T_{NO^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{O_{2}^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} = \frac{(0.24N_{NO^{+}})^{2}}{T_{NO^{+}}^{5}}
# 		$
#
# 		\vspace{1cm}
# 		\begin{equation*}
# 	\begin{split}
# 		\boxed{ \textbf{ 3)} \dd{v_{NO^{+}}}^{2} = \dd{v_{NO^{+}-O}}^{2} + \dd{v_{NO^{+}-O_{2}}}^{2} + \dd{v_{NO^{+}-N_{2}}}^{2}+ \dd{v_{NO^{+}-e}}^{2} + \dd{v_{NO^{+}-NO^{+}}}^{2}  + } \\
# 	\boxed{	+ \dd{v_{NO^{+}-O^{+}}}^{2} + \dd{v_{NO^{+}-O_{2}^{+}}}^{2} }
# 	\end{split}
# \end{equation*}
#
#
# 		\vspace{1cm}
# 		$
# 		\dagger v_{NO^{+}-O} = 2.44 \times 10^{10} N_{O}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-O_{2}} = 4.27 \times 10^{10} N_{O_{2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-N_{2}} = 4.39 \times 10^{10} N_{N_{2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-e} = \frac{54.5N_{NO^{+}} Z_{NO^{+}}^{2}}{T_{e}^{3/2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-NO^{+}} = \frac{0.16N_{NO^{+}}}{T_{NO^{+}}^{3/2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-O^{+}} = \frac{0.14N_{O^{+}}}{T_{O^{+}}^{3/2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{NO^{+}-O_{2}^{+}} = \frac{0.17N_{O_{2}^{+}}}{T_{O_{2}^{+}}^{3/2}}
# 		$
#
# 		\vspace{1cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-O}}^{2} = \mid \pdv{v_{NO^{+}-O}}{N_{O}} \mid ^{2} .\dd{N_{O}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O}}{N_{O}} \mid ^{2} = (2.44 \times 10^{10})^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-O_{2}}}^{2} = \mid \pdv{v_{NO^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} .\dd{N_{O_{2}}}^{2}
# 		$
#
# 			\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O_{2}}}{N_{O_{2}}} \mid ^{2} = (4.27 \times 10^{10})^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-N_{2}}}^{2} = \mid \pdv{v_{NO^{+}-N_{2}}}{N_{N_{2}}} \mid ^{2} .\dd{N_{N_{2}}}^{2}
# 		$
#
# 			\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-N_{2}}}{N_{N_{2}}} \mid ^{2} = (4.39 \times 10^{10})^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-e}}^{2} = \mid \pdv{v_{NO^{+}-e}}{N_{NO^{+}}} \mid ^{2} .\dd{N_{NO^{+}}}^{2} +
# 		\mid \pdv{v_{NO^{+}-e}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-e}}{N_{NO^{+}}} \mid ^{2} = \frac{(54.5 Z_{NO^{+}}^{2})^{2}}{T_{e}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-e}}{T_{e}} \mid ^{2} = \frac{(81.75 N_{NO^{+}} Z_{NO^{+}}^{2})^{2}}{T_{e}^{5}}
# 		$
#
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-NO^{+}}}^{2} = \mid \pdv{v_{NO^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} .\dd{N_{NO^{+}}}^{2} +
# 		\mid \pdv{v_{NO^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} .\dd{T_{NO^{+}}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-NO^{+}}}{N_{NO^{+}}} \mid ^{2} = \frac{(0.16)^{2}}{T_{NO^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-NO^{+}}}{T_{NO^{+}}} \mid ^{2} = \frac{(0.24N_{NO^{+}} )^{2}}{T_{NO^{+}}^{5}}
# 		$
#
#
#
#
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-O^{+}}}^{2} = \mid \pdv{v_{NO^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} .\dd{N_{O^{+}}}^{2} +
# 		\mid \pdv{v_{NO^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} .\dd{T_{O^{+}}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O^{+}}}{N_{O^{+}}} \mid ^{2} = \frac{(0.14)^{2}}{T_{O^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O^{+}}}{T_{O^{+}}} \mid ^{2} = \frac{(0.21N_{O^{+}} )^{2}}{T_{O^{+}}^{5}}
# 		$
#
#
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{NO^{+}-O_{2}^{+}}}^{2} = \mid \pdv{v_{NO^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} .\dd{N_{O_{2}^{+}}}^{2} +
# 		\mid \pdv{v_{NO^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} .\dd{T_{O_{2}^{+}}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O_{2}^{+}}}{N_{O_{2}^{+}}} \mid ^{2} = \frac{(0.17)^{2}}{T_{O_{2}^{+}}^{3}}
# 		$
#
# 		\vspace{0.3cm}
# 		$
# 		\rightarrow \mid \pdv{v_{NO^{+}-O_{2}^{+}}}{T_{O_{2}^{+}}} \mid ^{2} = \frac{(0.255N_{O_{2}^{+}} )^{2}}{T_{O_{2}^{+}}^{5}}
# 		$
#
#
#
# 		\vspace{1cm}
# 		$
# 	  \boxed{ \textbf{ 4) } \dd{v_{e}}^{2} = \dd{v_{e-e}}^{2} + \dd{v_{e-O}}^{2} + \dd{v_{e-O_{2}}}^{2} + \dd{v_{e-N_{2}}}^{2}  }
# 		$
#
# 		\vspace{1cm}
# 		$
# 		\dagger v_{e-e} = \frac{54.5 N_{e}}{\sqrt{2}T_{e}^{3/2}}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{e-O} = 8.9 \times 10^{-11}N_{O}(1 + 5.7 \times 10^{-4}T_{e})T_{e}^{1/2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{e-O_{2}} = 1.82 \times 10^{-10}N_{O_{2}}(1 + 3.6 \times 10^{-2}T_{e}^{1/2})T_{e}^{1/2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\dagger v_{e-N_{2}} = 2.33 \times 10^{-11}N_{N_{2}}(1 - 1.21 \times 10^{-4}T_{e})T_{e}
# 		$
#
# 			\vspace{1cm}
# 		$
# 		\bullet \dd{v_{e-e}}^{2} = \mid \pdv{v_{e-e}}{N_{e}} \mid ^{2} .\dd{N_{e}}^{2} + \mid \pdv{v_{e-e}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 		$
#
# 			\vspace{0.5cm}
# 			$
# 			\rightarrow \mid \pdv{v_{e-e}}{N_{e}} \mid ^{2} = \frac{54.5^{2}}{2T_{e}^{3}}
# 			$
#
# 			\vspace{0.5cm}
# 			$
# 			\rightarrow \mid \pdv{v_{e-e}}{T_{e}} \mid ^{2} = \frac{(81.75 N_{e})^{2}}{2 T_{3}^{5}}
# 			$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{e-O}}^{2} = \mid \pdv{v_{e-O}}{N_{O}} \mid ^{2} .\dd{N_{O}}^{2} + \mid \pdv{v_{e-O}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 		$
#
# 			\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-O}}{N_{O}} \mid ^{2} = 8.9 \times 10^{-11} (1 + 5.7 \times 10^{-4} T_{e})T_{e}^{1/2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-O}}{T_{e}} \mid ^{2} = N_{O}^{2}[4.45 \times 10^{-11} T_{e}^{-1/2} + 76.095 \times 10^{-15} T_{e}^{1/2}]^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{e-O_{2}}}^{2} = \mid \pdv{v_{e-O_{2}}}{N_{O_{2}}} \mid ^{2} .\dd{N_{O_{2}}}^{2} + \mid \pdv{v_{e-O_{2}}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-O_{2}}}{N_{O_{2}}} \mid ^{2} = 1.82 \times 10^{-10} (1 + 3.6 \times 10^{-2} T_{e}^{1/2})T_{e}^{1/2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-O_{2}}}{T_{e}} \mid ^{2} = N_{O_{2}}^{2}[0.91 \times 10^{-10} T_{e}^{-1/2} + 6.552 \times 10^{-12}]^{2}
# 		$
#
#
# 			\vspace{0.5cm}
# 		$
# 		\bullet \dd{v_{e-N_{2}}}^{2} = \mid \pdv{v_{e-N_{2}}}{N_{N_{2}}} \mid ^{2} .\dd{N_{N_{2}}}^{2} + \mid \pdv{v_{e-N_{2}}}{T_{e}} \mid ^{2} .\dd{T_{e}}^{2}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-N_{2}}}{N_{N_{2}}} \mid ^{2} = 2.33 \times 10^{-11} (1 - 1.21 \times 10^{-4} T_{e})T_{e}
# 		$
#
# 		\vspace{0.5cm}
# 		$
# 		\rightarrow \mid \pdv{v_{e-N_{2}}}{T_{e}} \mid ^{2} = N_{N_{2}}^{2}[2.33 \times 10^{-11} - 5.6386 \times 10^{-15}T_{e}]^{2}
# 		$
