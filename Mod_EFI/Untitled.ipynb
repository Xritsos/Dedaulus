# %%
file_IRI="DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_IRI16_all.csv"

# %%
Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)

# %%
import pandas as pd

# %%
Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)

# %%
daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]    # in 1/cm3
    n_Op = Model_Data["O+_iri16_cm-3"]   # in 1/cm3
    n_O2p = Model_Data["O2+_iri16_cm-3"] # in 1/cm3
    n_NOp = Model_Data["NO+_iri16_cm-3"]  # in 1/cm3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    T_Op = T_i
    T_NOp = T_i

# %%
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]    # in 1/cm3
    n_Op = Model_Data["O+_iri16_cm-3"]   # in 1/cm3
    n_O2p = Model_Data["O2+_iri16_cm-3"] # in 1/cm3
    n_NOp = Model_Data["NO+_iri16_cm-3"]  # in 1/cm3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    T_Op = T_i
    T_NOp = T_i

# %%
ne.shape

# %%
n_e.shape

# %%
daed_time.shape

# %%
n_e[0:100]

# %%
n_e[2000]

# %%
n_Op[2000]

# %%
n_e[2000]-n_Op[2000]_n_O2p[2000]-n_NOp[2000]

# %%
n_e[2000]-n_Op[2000]-n_O2p[2000]-n_NOp[2000]

# %%
n_NOp[2000]

# %%
n_O2p[2000]

# %%
i=3000

# %%
n_e[i]-n_Op[i]-n_O2p[i]-n_NOp[i]

# %%
n_e[i]

# %%
n_Op[i]

# %%
n_O2p[i]

# %%
n_e[i]-n_Op[i]

# %%
n_i = n_e-n_Op

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat00_Srt01Hz_Msc.csv"

# %%
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]    # in km/s
    RamY = Ram_Data["RamY_GSE"]    # in km/s
    RamZ = Ram_Data["RamZ_GSE"]    # in km/s
    V_ram = Ram_Data["VMag(km/s)"]

# %%
RamX.shape

# %%
n_i.shape

# %%
    e0 = 8.85e-12    # permitivity of free space
    qe = 1.6e-19     # fundamental charge in Coloumb
    Kb = 1.38e-23    # Boltzman constant
    me = 9.11e-31    # electron mass in kg
    mi = 1.67e-27    # ion mass in kg
    mOp = 16.0 * mi   # Oxygen mass in kg

# %%
    length = 0.3     # 30 cm
    radius = 0.1     # 10 cm
    
    A_full = 2. * np.pi * radius * length   # Fully cylinder 
    A_ram  = length * radius                # Cross-sectional area

# %%
    Vsc = 1.0 #(findgen(200) / 100. - 1.)*2. #between -2 and 2 Volts

# %%
    alpha = 0.05
    V1 = 2.7 # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0 # 20 to 60 microA/m^2 at 1AU
    #Aphoto = ?     # illuminated Area

    Jphoto = jphoto0*( (1-alpha)*np.exp(-Vsc/V1) + alpha*np.exp(-Vsc/V2) )  # Vsc >= 0
    Jphoto = jphoto0  # Vsc < 0

# %%
Jphoto.shape

# %%
Jphoto

# %%
    Jphoto = jphoto0*( (1-alpha)*np.exp(-Vsc/V1) + alpha*np.exp(-Vsc/V2) )  # Vsc >= 0

# %%
    Jthe0     = np.sqrt( kb * T_e / me ) * n_e * qe   # !!!! Is qe negative?
    Jthi0     = np.sqrt( kb * T_i / mi ) * n_i * qe
    Jtho0     = np.sqrt( kb * T_Op / mo ) * n_Op * qe

# %%
    Jthe0     = np.sqrt( Kb * T_e / me ) * n_e * qe   # !!!! Is qe negative?
    Jthi0     = np.sqrt( Kb * T_i / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op / mo ) * n_Op * qe

# %%
    Jthe0     = np.sqrt( Kb * T_e / me ) * n_e * qe   # !!!! Is qe negative?
    Jthi0     = np.sqrt( Kb * T_i / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op / mOp ) * n_Op * qe

# %%
A_ram

# %%
V_ram.shape

# %%
    I_e_ram     = A_ram * V_ram * qe * n_e
    I_i_ram     = A_ram * V_ram * qe * n_i
    I_o_ram     = A_ram * V_ram * qe * n_Op

# %%
    I_e_thermal  = A_full * Jthe0 * np.sqrt(1d + qe*Vsc / (Kb * T_e) )
    I_i_thermal  = A_full * Jthi0 * np.exp( -qe * Vsc / (Kb * T_i) )
    I_o_thermal  = A_full * Jtho0 * np.exp( -qe * Vsc / (Kb * T_Op) )

# %%
    I_e_thermal  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc / (Kb * T_e) )
    I_i_thermal  = A_full * Jthi0 * np.exp( -qe * Vsc / (Kb * T_i) )
    I_o_thermal  = A_full * Jtho0 * np.exp( -qe * Vsc / (Kb * T_Op) )

# %%
    I_photo     = 0.0

# %%
    I_total     = I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram

# %%
I_total.shape

# %%
plt.plot(I_total)

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

# %%
plt.plot(I_total)

# %%
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3

# %%
    Jthe0     = np.sqrt( Kb * T_e / me ) * n_e * qe   # !!!! Is qe negative?
    Jthi0     = np.sqrt( Kb * T_i / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op / mOp ) * n_Op * qe

# %%
    I_e_thermal  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc / (Kb * T_e) )
    I_i_thermal  = A_full * Jthi0 * np.exp( -qe * Vsc / (Kb * T_i) )
    I_o_thermal  = A_full * Jtho0 * np.exp( -qe * Vsc / (Kb * T_Op) )



    #=============
    # Ram Current
    #=============

    I_e_ram     = A_ram * V_ram * qe * n_e
    I_i_ram     = A_ram * V_ram * qe * n_i
    I_o_ram     = A_ram * V_ram * qe * n_Op

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

# %%
plt.plot(I_total)

# %%
    X_GSE = Ram_Data["X_GSE(km))"]     # in km
    Y_GSE = Ram_Data["Y_GSE(km))"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km))"]     # in km

# %%
file_IRI="DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_IRI16_all.csv"
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat00_Srt01Hz_Msc.csv"
outfile="Resistance_Products"

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i

# %%
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km))"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km))"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km))"]     # in km

# %%
RamX.shape

# %%
    X_GSE = Ram_Data["X_GSE(km))"]     # in km

# %%
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

# %%
X_GSE.shape

# %%
    RE = 6371.0         # in km

# %%
    length = 5.0     # in m
    radius = 0.06     # 6 cm
    
    A_full = 4. * np.pi * radius * radius   # Fully Sphere
    A_ram  = np.pi * radius * radius        # Cross-sectional area

# %%
    Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
plt.plot(Lambda_D)

# %%
    Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

# %%
Vsc.shape

# %%
np.where(Vsc >0)

# %%
Vsc(np.where(Vsc >0))

# %%
    Jthe0     = np.sqrt( Kb * T_e / me ) * n_e * qe   
    Jthi0     = np.sqrt( Kb * T_i / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op / mOp ) * n_Op * qe

# %%
    I_e_thermal = A_full * Jthe0 * np.exp( qe * Vsc / (Kb * T_e) )
    I_i_thermal = A_full * Jthi0 * np.sqrt(1. - qe*Vsc / (Kb * T_i) )
    I_o_thermal = A_full * Jtho0 * np.sqrt(1. - qe*Vsc / (Kb * T_Op) )

# %%
daed_time.shape

# %%
daed_time.shape(0)

# %%
daed_time.shape[0]

# %%
    npoints = daed_time.shape[0]

# %%
k=0

# %%
T_e[k]

# %%
k=1000
T_e[k]

# %%
k=5000
T_e[k]

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

# %%
Jthe0.shape

# %%
print(Jthe0)

# %%
    I_e_thermal = A_full * Jthe0 * np.exp( qe * Vsc / (Kb * T_e[k]) )
    I_i_thermal = A_full * Jthi0 * np.sqrt(1. - qe*Vsc / (Kb * T_i[k]) )
    I_o_thermal = A_full * Jtho0 * np.sqrt(1. - qe*Vsc / (Kb * T_Op[k]) )

# %%
1. - qe*Vsc / (Kb * T_Op[k])

# %%
    I_e_thermal = np.zeros(200)

# %%
Vsc[np.where(Vsc >0)]

# %%
    I_e_thermal[np.where(Vsc >0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc >0)] / (Kb * T_e[k]) )

# %%
print(I_e_thermal)

# %%
Vsc[np.where(Vsc >0)].shape

# %%
    I_e_thermal[np.where(Vsc >0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc >0)] / (Kb * T_e[k]) )

# %%
    I_e_thermal = np.zeros(200)

# %%
    I_e_thermal[np.where(Vsc >0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc >0)] / (Kb * T_e[k]) )

# %%
print(I_e_thermal)

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )

# %%
    I_e_thermal = np.zeros(200)

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )

# %%
I_e_thermal[np.where(Vsc <0)]

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )

# %%
1. - qe*Vsc[np.where(Vsc <0)

# %%
1. - qe*Vsc[np.where(Vsc <0)]

# %%
qe*Vsc[np.where(Vsc <0)]

# %%
np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)

# %%
    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )

# %%
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )

# %%
print(Jthi0)

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )

# %%
print(Jthi0)

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

# %%
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )

# %%
print(I_e_thermal)

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )

# %%
print(I_e_thermal)

# %%
I_e_thermal.shape

# %%
    I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
    I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
    I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

# %%
I_photo=0

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

# %%
plt.plot(I_total)

# %%
plt.plot(I_total)

# %%
plt.plot(Vsc,I_total)

# %%
    R = 1./np.gradient(I_total, Vsc)

# %%
    R = 1./np.gradient(I_total, Vsc)

# %%
plt.plot(Vsc, R)

# %%
np.dtype(R)

# %%
R.dtype

# %%
Te.shape

# %%
T_e[k]

# %%
T_i[k]

# %%
ne[k]

# %%
n_e[k]

# %%
plt.plot(Vsc, I_total)

# %%
np.where(I_total <=0)

# %%
np.where(I_total =0)

# %%
np.where(I_total ==0)

# %%
print(I_total[0:36])

# %%
print(I_total[0:37])

# %%
print(I_total[0:38])

# %%
Vsc[38]

# %%
R[38]

# %%
n_e[k]=1e11
n_i[k]=n_e[k]*0.05
n_Op[k]=n_e[k]*0.95

# %%
print(T_e[k])

# %%
T_e[k]=0.5e3

# %%
T_e[k]=5e2

# %%
T_e[k]

# %%
T_i[k]=T_e[k]/2.

# %%
T_Op[k]=T_i[k]

# %%
print(T_i[k])

# %%
V_ram[k]

# %%
V_ram[k]=7.8e3

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

    #================
    # Thermal currents for positive spacecraft potential Vsc >=0
    #================
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


    #================
    # Thermal currents for negative spacecraft potential Vsc < 0
    #================

    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




    #=============
    # Ram Current V_ram is total ram velocity
    #=============

    I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
    I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
    I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

# %%
plt.plot(Vsc, I_total)

# %%
    R = 1./np.gradient(I_total, Vsc)

# %%
plt.plot(Vsc,R)

# %%
plt.plot(Vsc,R/1e6)

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0 # 20 to 60 microA/m^2 at 1AU

# %%
    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0

# %%
Jphoto

# %%
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0

# %%
Jphoto

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

# %%
    R = 1./np.gradient(I_total, Vsc)

# %%
plt.plot(Vsc, I_total)

# %%
X_GSE[k]

# %%
Y_GSE[k]

# %%
Z_GSE[k]

# %%
plt.plot(Vsc, R)

# %%
plt.plot(Vsc, R/1e6)

# %%
np.where(I_total<=0)

# %%
I_total[90]

# %%
I_total[91]

# %%
R[90]

# %%
A_photo

# %%
    A_photo = A_ram

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*Aphoto

# %%
    I_photo     = Jphoto*A_photo

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

    
    R = 1./np.gradient(I_total, Vsc)

# %%
plt.plot(Vsc, R/1e6)

# %%
plt.plot(Vsc, I_total*1e3)

# %%
plt.plot(Vsc, I_total)

# %%
np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE)

# %%
file_IRI="DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_IRI16_all.csv"
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat00_Srt01Hz_Msc.csv"
outfile="Resistance_Products"

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    
    k = 5000

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    
    k = 5000

# %%
    e0 = 8.85e-12    # permitivity of free space
    qe = 1.6e-19     # fundamental charge in Coloumb
    Kb = 1.38e-23    # Boltzman constant
    me = 9.11e-31    # electron mass in kg
    mi = 1.67e-27    # ion mass in kg
    mOp = 16.0 * mi   # Oxygen mass in kg
    #mO2p = 16.0 * mi   # Oxygen mass in kg
    #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
    RE = 6371.0         # in km
    #=============
    # Boom Dimensions
    #=============
    length = 5.0     # in m
    radius = 0.06     # 6 cm
    
    A_full = 4. * np.pi * radius * radius   # Fully Sphere
    A_ram  = np.pi * radius * radius        # Cross-sectional area

# %%
    Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0e-3 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*A_photo
    
   # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
    # This goes into the for loop along the orbit.
    
    if ( (X_GSE < 0) and (np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE)> RE) ):
        I_photo = 0.0

# %%
    if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
I_photo

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0e-3 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*A_photo

# %%
plt.plot(Vsc,I_photo)

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

    #================
    # Thermal currents for positive spacecraft potential Vsc >=0
    #================
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




    #=============
    # Ram Current V_ram is total ram velocity
    #=============

    I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
    I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
    I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

    
    R = 1./np.gradient(I_total, Vsc)

# %%
    plt.plot(Vsc, I_total)

# %%
    plt.plot(Vsc, R)

# %%
I_photo = 0.0

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

    
    R = 1./np.gradient(I_total, Vsc) 

    plt.plot(Vsc, I_total)

# %%
    plt.plot(Vsc, R)

# %%
npoints

# %%
T_e[1000]

# %%
T_e[2000]

# %%
k=2000

# %%
if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
I_photo

# %%
I_photo=1.0

# %%
if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
I_photo

# %%
k=2000

# %%
T_e[k]

# %%
if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
I_photo

# %%
n_e[k]

# %%
    k = 2000

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0e-3 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*A_photo
    
   # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
    # This goes into the for loop along the orbit.
    
    if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
plt.plot(Vsc, I_photo)

# %%
    Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
    Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
    Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

    #================
    # Thermal currents for positive spacecraft potential Vsc >=0
    #================
    I_e_thermal = np.zeros(200)
    I_i_thermal = np.zeros(200)
    I_o_thermal = np.zeros(200)


    I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )

# %%
    I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
    I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
    I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




    #=============
    # Ram Current V_ram is total ram velocity
    #=============

    I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
    I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
    I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

    
    R = 1./np.gradient(I_total, Vsc) 

    plt.plot(Vsc, I_total)

# %%
plt.plot(Vsc, I_e_thermal)

# %%
plt.plot(Vsc,-(0.0 - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram))

# %%
alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*A_photo

# %%
    alpha = 0.05
    V1 = 2.7   # volts empirical photoeletron energy
    V2 = 10.0  #volts empirical photoeletron energy
    jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

    Jphoto = np.zeros(200)
    
    Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
    Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
    A_photo = A_ram
    I_photo     = Jphoto*A_photo
    
   # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
    # This goes into the for loop along the orbit.
    
    if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
        I_photo = 0.0

# %%
I_photo

# %%
    I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)

    
    R = 1./np.gradient(I_total, Vsc) 

    plt.plot(Vsc, I_total)

# %%
    plt.plot(Vsc, R)

# %%
    plt.plot(Vsc, R/1e6)

# %%
np.where(I_total <=0)

# %%
np.where(I_total <=0)

# %%
a=np.where(I_total <=0)

# %%
a.shape

# %%
a

# %%
a.size

# %%
I_total[57]

# %%
I_total[58]

# %%
np.asarray(I_total <=0)

# %%
np.asarray(I_total <=0).nonzero()

# %%
a=np.asarray(I_total <=0).nonzero()

# %%
a[-1]

# %%
a[-1][-1]

# %%
a[0][-1]

# %%
    IL0 = np.asarray(I_total <=0).nonzero()
    I0 = IL0[0][-1]

# %%
I_total[I0]

# %%
type(a)

# %%
    IL0_ind = np.asarray(I_total <=0).nonzero()
    I0_ind = IL0[0][-1]
    
    Rs[k] = R[I0_ind]

# %%
    Rs = np.zeros[npoints]

# %%
    Rs = np.zeros(npoints)

# %%
    Rs[k] = R[I0_ind]

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

# %%
    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)

# %%
    for k in range(2000,npoints):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero()
        I0_ind = IL0[0][-1]

        Rs[k] = R[I0_ind]

# %%
Rs.shape

# %%
plt.plot(Rs/1e6)

# %%
plt.plot(X_GSE,Rs/1e6)

# %%
plt.plot(Rs/1e6)

# %%
plt.plot(Rs/1e6)
plt.plot(X_GSE/RE)

# %%
T_e[1620]

# %%
T_e[1619]

# %%
T_e[1618]

# %%
T_e[1617]

# %%
T_e[1616]

# %%
T_e[1615]

# %%
T_e[5418]

# %%
T_e[5417]

# %%
T_e[5416]

# %%
    for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero()
        I0_ind = IL0[0][-1]

        Rs[k] = R[I0_ind]

# %%
plt.plot(Rs/1e6)
plt.plot(X_GSE/RE)

# %%
plt.plot(Rs/1e6)
plt.plot(X_GSE/RE)
plt.plot(Y_GSE/RE)
plt.plot(Z_GSE/RE)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
file_IRI="DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_IRI16_all.csv"
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat00_Srt01Hz_Msc.csv"

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)

# %%
    for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero()
        I0_ind = IL0[0][-1]

        Rs[k] = R[I0_ind]

# %%
    for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero()
        I0_ind = IL0_ind[0][-1]

        Rs[k] = R[I0_ind]

# %%
plt.plot(Rs/1e6)
plt.plot(X_GSE/RE)
plt.plot(Y_GSE/RE)
plt.plot(Z_GSE/RE)

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt((X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE))
plt.plot(X_GSE/RE)

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt(X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE)
plt.plot(X_GSE/RE)

# %%
plt.plot(np.sqrt(X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE)

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt((X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE))
plt.plot(X_GSE/RE)
plt.ylabel("R in Mohms")

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt(X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE)
plt.plot(X_GSE/RE)
plt.ylabel("Resistance")

# %%
    plt.plot(I_total)

# %%
I0_ind

# %%
I_total[25]

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt(X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE)
plt.plot(X_GSE/RE)
plt.ylabel("R in Mohms")

# %%
plt.plot(X_GSE/RE)
plt.plot(Y_GSE/RE)
plt.plot(Z_GSE/RE)

# %%
plt.plot(X_GSE/RE)
plt.plot(Y_GSE/RE)

# %%
plt.plot(Rs/1e6)
plt.plot(np.sqrt(X_GSE*X_GSE+Y_GSE*Y_GSE+Z_GSE*Z_GSE)/RE)
plt.plot(X_GSE/RE)
plt.ylabel("R in Mohms")

# %%
plt.plot(X_GSE/RE)
plt.plot(Y_GSE/RE)
plt.plot(Z_GSE/RE)

# %%
X_GSE[0]

# %%
np.sqrt(X_GSE[0]*X_GSE[0]+Y_GSE[0]*Y_GSE[0]+Z_GSE[0]*Z_GSE[0])

# %%
np.sqrt(X_GSE[0]*X_GSE[0]+Y_GSE[0]*Y_GSE[0]+Z_GSE[0]*Z_GSE[0])-RE

# %%
    plt.plot(Rs/1e6)

    plt.ylabel("Resistance")

# %%
np.minimum(Rs)

# %%
plt.plot(Rs/1e6)
plt.yscale('log')

# %%
plt.plot(Vsc,I_total)

# %%
plt.plot(Vsc,I_total/1e-6)

# %%
I_total(I0_ind)

# %%
I_total[I0_ind]

# %%
I0_ind

# %%
Vsc[25]

# %%
plt.plot(I_photo)

# %%
I_photo

# %%
plt.plot(I_e_thermal)

# %%
plt.plot(I_e_thermal)
plt.plot(I_total)

# %%
I_total[I0_ind+1]

# %%
R[I0_ind]

# %%
R[I0_ind+1]

# %%
Vsc[0]

# %%
Vsc[100]

# %%
Vsc[99]

# %%
Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
    for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero() # make it better
        I0_ind = IL0_ind[0][-1]

        Rs[k] = R[I0_ind]
        V_I0[k] = Vsc[I0_ind]
        I_V0[k] = I_total[100]

# %%
plt.plot(Rs/1e6)

# %%
    plt.plot(V_I0)

# %%
plt.plot(I_V0)

# %%
file_IRI='DAED_ORB_Evt1_LLA_Per120_Lat80_Srt01Hz_Msc_IRI16_all.csv'
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat80_Srt01Hz_Msc.csv"

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
T_e[1616]

# %%
T_e[1610]

# %%
T_e[1600]

# %%
T_e[5416]

# %%
T_e[6000]

# %%
T_e[5500]

# %%
   for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero() # make it better
        I0_ind = IL0_ind[0][-1]

        Rs[k] = R[I0_ind]
        V_I0[k] = Vsc[I0_ind]
        I_V0[k] = I_total[100]

# %%
plt.plot(Rs/1e6)

# %%
npoints

# %%
    npoints = daed_time.shape[0]

# %%
npoints

# %%
npoints

# %%
file_IRI='DAED_ORB_Evt1_LLA_Per120_Lat80_Srt01Hz_Msc_IRI16_all.csv'
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat80_Srt01Hz_Msc.csv"

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
npoints

# %%
daed_time.shape

# %%
file_IRI='DAED_ORB_Evt1_LLA_Per120_Lat80_Srt01Hz_Msc_IRI16_all.csv'
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat80_Srt01Hz_Msc.csv"

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
npoints

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
npoints

# %%
file_IRI='DAED_ORB_Evt0_LLA_Per120_Lat80_Srt01Hz_Msc_IRI16_all.csv'
file_Velocities="DAED_ORB_Evt0_PTG_Per120_Lat80_Srt01Hz_Msc.csv"

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-18dabf0e4a92> in <module>
# ----> 1 Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
#       2 daed_time = Model_Data["Epoch(UTCG)"]
#       3 daed_lat = Model_Data["Lat_GEOD(deg)"]
#       4 daed_lon = Model_Data["Lon_GEOD(deg)"]
#       5 daed_alt = Model_Data["Height_WGS84 (km)"]
#
# NameError: name 'pd' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import FortranFile
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from pandas import DataFrame

# %%
    Model_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_IRI)
    daed_time = Model_Data["Epoch(UTCG)"]
    daed_lat = Model_Data["Lat_GEOD(deg)"]
    daed_lon = Model_Data["Lon_GEOD(deg)"]
    daed_alt = Model_Data["Height_WGS84 (km)"]
    n_e = Model_Data["ne_iri16_cm-3"]*1e6    # in 1/m3
    n_Op = Model_Data["O+_iri16_cm-3"]*1e6   # in 1/m3
    n_i = n_e-n_Op
    #n_O2p = Model_Data["O2+_iri16_cm-3"]*1e6 # in 1/m3
    #n_NOp = Model_Data["NO+_iri16_cm-3"]*1e6  # in 1/m3
    T_e = Model_Data["Te_iri16_K"]       # in K
    T_i = Model_Data["Ti_iri16_K"]       # in K
    T_Op = T_i
    #T_O2p = T_i
    #T_NOp = T_i
    
    Ram_Data = pd.read_csv("~/DaedalusMaze/DataFiles/OrbitData/"+file_Velocities)
    RamX = Ram_Data["RamX_GSE"]*1e3    # in m/s
    RamY = Ram_Data["RamY_GSE"]*1e3    # in m/s
    RamZ = Ram_Data["RamZ_GSE"]*1e3    # in m/s
    V_ram = Ram_Data["VMag(km/s)"]*1e3 # in m/s
    X_GSE = Ram_Data["X_GSE(km)"]     # in km 
    Y_GSE = Ram_Data["Y_GSE(km)"]     # in km
    Z_GSE = Ram_Data["Z_GSE(km)"]     # in km

    npoints = daed_time.shape[0]
    Rs = np.zeros(npoints)
    V_I0 = np.zeros(npoints)
    I_V0 = np.zeros(npoints)

# %%
npoints
# Out:
# 7080

# %%
    for k in range(1616,5416):
        print('k =', k)
         # ******************************************************************************************
        #=============
        # Constants
        #=============

        e0 = 8.85e-12    # permitivity of free space
        qe = 1.6e-19     # fundamental charge in Coloumb
        Kb = 1.38e-23    # Boltzman constant
        me = 9.11e-31    # electron mass in kg
        mi = 1.67e-27    # ion mass in kg
        mOp = 16.0 * mi   # Oxygen mass in kg
        #mO2p = 16.0 * mi   # Oxygen mass in kg
        #mNOp = 16.0 * mi   # Oxygen and Nitrogen mass in kg
        RE = 6371.0         # in km
        #=============
        # Boom Dimensions
        #=============
        length = 5.0     # in m
        radius = 0.06     # 6 cm

        A_full = 4. * np.pi * radius * radius   # Fully Sphere
        A_ram  = np.pi * radius * radius        # Cross-sectional area

        #Lambda_D = np.sqrt( e0 * Kb * T_e / (n_e * qe * qe))

        #================
        # For different values of spacecraft potential 
        #===============

        Vsc = np.linspace(-2.0,2.0,200)  #between -2 and 2 Volts

        # ******************************************************************************************
        #=============
        # Currents
        #=============

        #=============
        # Photoelectron Current
        #=============

        alpha = 0.05
        V1 = 2.7   # volts empirical photoeletron energy
        V2 = 10.0  #volts empirical photoeletron energy
        jphoto0 = 20.0e-6 # 20 to 60 microA/m^2 at 1AU

        Jphoto = np.zeros(200)

        Jphoto[np.where(Vsc >=0)] = jphoto0*( (1.0-alpha)*np.exp(-Vsc[np.where(Vsc >=0)]/V1) + alpha*np.exp(-Vsc[np.where(Vsc >=0)]/V2) )  # Vsc >= 0
        Jphoto[np.where(Vsc <0)] = jphoto0  # Vsc < 0 
        A_photo = A_ram
        I_photo     = Jphoto*A_photo

       # Finding shadows in orbit X_GSE < 0 AND np.sqrt(Y_GSE*Y_GSE + Z_GSE*Z_GSE) > 1 RE -> I_photo = 0 in shadow
        # This goes into the for loop along the orbit.

        if ( (X_GSE[k] < 0) and (np.sqrt(Y_GSE[k]*Y_GSE[k] + Z_GSE[k]*Z_GSE[k])> RE) ):
            I_photo = 0.0


        #=============
        # Thermal currents -- thermal velocity sqrt(kb Tj/mj), j = i, e, o
        #=============

        Jthe0     = np.sqrt( Kb * T_e[k] / me ) * n_e[k] * qe   
        Jthi0     = np.sqrt( Kb * T_i[k] / mi ) * n_i[k] * qe
        Jtho0     = np.sqrt( Kb * T_Op[k] / mOp ) * n_Op[k] * qe

        #================
        # Thermal currents for positive spacecraft potential Vsc >=0
        #================
        I_e_thermal = np.zeros(200)
        I_i_thermal = np.zeros(200)
        I_o_thermal = np.zeros(200)


        I_e_thermal[np.where(Vsc >=0)]  = A_full * Jthe0 * np.sqrt(1.0 + qe*Vsc[np.where(Vsc >=0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc >=0)]  = A_full * Jthi0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc >=0)]  = A_full * Jtho0 * np.exp( -qe * Vsc[np.where(Vsc >=0)] / (Kb * T_Op[k]) )


        #================
        # Thermal currents for negative spacecraft potential Vsc < 0
        #================

        I_e_thermal[np.where(Vsc <0)] = A_full * Jthe0 * np.exp( qe * Vsc[np.where(Vsc <0)] / (Kb * T_e[k]) )
        I_i_thermal[np.where(Vsc <0)] = A_full * Jthi0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_i[k]) )
        I_o_thermal[np.where(Vsc <0)] = A_full * Jtho0 * np.sqrt(1. - qe*Vsc[np.where(Vsc <0)] / (Kb * T_Op[k]) )




        #=============
        # Ram Current V_ram is total ram velocity
        #=============

        I_e_ram     = A_ram * V_ram[k] * qe * n_e[k]
        I_i_ram     = A_ram * V_ram[k] * qe * n_i[k]
        I_o_ram     = A_ram * V_ram[k] * qe * n_Op[k]

        #================
        # Total current
        #================

        I_total     = -(I_photo - I_e_thermal + I_i_thermal + I_o_thermal + I_i_ram + I_o_ram - I_e_ram)


        R = 1./np.gradient(I_total, Vsc) 

        plt.plot(Vsc, I_total)
        plt.plot(Vsc, R)

        IL0_ind = np.asarray(I_total <=0).nonzero() # make it better
        I0_ind = IL0_ind[0][-1]

        Rs[k] = R[I0_ind]
        V_I0[k] = Vsc[I0_ind]
        I_V0[k] = I_total[100]
# Out:
# k = 1616
# k = 1617
# k = 1618
# k = 1619
# k = 1620
# k = 1621
# k = 1622
# k = 1623
# k = 1624
# k = 1625
# k = 1626
# k = 1627
# k = 1628
# k = 1629
# k = 1630
# k = 1631
# k = 1632
# k = 1633
# k = 1634
# k = 1635
# k = 1636
# k = 1637
# k = 1638
# k = 1639
# k = 1640
# k = 1641
# k = 1642
# k = 1643
# k = 1644
# k = 1645
# k = 1646
# k = 1647
# k = 1648
# k = 1649
# k = 1650
# k = 1651
# k = 1652
# k = 1653
# k = 1654
# k = 1655
# k = 1656
# k = 1657
# k = 1658
# k = 1659
# k = 1660
