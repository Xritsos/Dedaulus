# %%
# %load_ext autoreload
# %autoreload 2
import SourceCode.DaedalusMazeGUI as DaedalusMazeGUI
import ipywidgets as widgets

MainPanel=DaedalusMazeGUI.createAll()
MainPanel
# Out:
# Tab(children=(VBox(children=(Dropdown(description='Select Group:', options=(' ', 'HWM14', 'IGRF', 'IRI16', 'In…
# /home/jupyter-kpapadakis/maze/SourceCode/ModulesSourceCode/Interpolator/Interpolator.py:120: UserWarning:
#
# WARNING: missing_value not used since it
# cannot be safely cast to variable data type
#
# /home/jupyter-kpapadakis/maze/SourceCode/ModulesSourceCode/Interpolator/Interpolator.py:123: UserWarning:
#
# WARNING: missing_value not used since it
# cannot be safely cast to variable data type
# Interpolation Starting... 1108 Positions to Interpolate
# Interpolation Done!
# Output Saved! Path--> ../../NAS/Data_Files/ModelsOutput/Interpolation/../../NAS/Data_Files/OrbitData/DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_TIEGCM_O2.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/maze/SourceCode/DaedalusMazeGUI.py in execute_button_clicked(b)
#      56         global AvailableGroups_dropdown
#      57         DisplayBusy()
# ---> 58         getattr( GroupsAction, 'Execute_'+str(AvailableGroups_dropdown.value) )()
#      59         DisplayDone()
#      60
#
# ~/maze/SourceCode/GroupsAction.py in Execute_Interpolator()
#      42         Display( '    Interpolator( ' , PanelDisplayer.WIDGET_Interpolator_model.value,', ' , PanelDisplayer.WIDGET_Interpolator_model_data_file.value,', ' , OrbitSelector_OrbitFilename,', ' , PanelDisplayer.WIDGET_Interpolator_save.value,', ' , PanelDisplayer.WIDGET_Interpolator_VAR.value , ' ) results:')
#      43         Display( '          InterpolatedOrbitCSV: ' + str(Interpolator_InterpolatedOrbitCSV) )
# ---> 44         PlotGlobe( PanelDisplayer.WIDGET_PlotGlobe_DataCSVfilename.value, Interpolator_InterpolatedOrbitCSV, PanelDisplayer.WIDGET_PlotGlobe_GraphTitle.value, PanelDisplayer.WIDGET_PlotGlobe_ColorbarTitle.value, PanelDisplayer.WIDGET_PlotGlobe_ColorscaleName.value )
#      45         Display( '    PlotGlobe( ' , PanelDisplayer.WIDGET_PlotGlobe_DataCSVfilename.value,', ' , Interpolator_InterpolatedOrbitCSV,', ' , PanelDisplayer.WIDGET_PlotGlobe_GraphTitle.value,', ' , PanelDisplayer.WIDGET_PlotGlobe_ColorbarTitle.value,', ' , PanelDisplayer.WIDGET_PlotGlobe_ColorscaleName.value , ' ) results:')
#      46         Display( '          -void-' )
#
# ~/maze/SourceCode/ModulesSourceCode/PlotGlobe/PlotGlobe.py in PlotGlobe(DataCSVfilename, OrbitDataCSVfilename, PlotTitle, ColorbarTitle, ColorscaleName)
#     164         DataMax = np.amax(Data)
#     165     # for the orbit
# --> 166     if len(OrbitDataCSVfilename) > 0:
#     167         orbitCSVreader = csv.reader( open( OrbitDataCSVfilename ) )
#     168         next( orbitCSVreader ) # ignore the csv header
#
# TypeError: object of type 'NoneType' has no len()
# Interpolation Starting... 1108 Positions to Interpolate
# Interpolation Done!
# Output Saved! Path--> ../../NAS/Data_Files/ModelsOutput/Interpolation/../../NAS/Data_Files/OrbitData/DAED_ORB_Evt0_LLA_Per120_Lat00_Srt01Hz_Msc_TIEGCM_NE.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/maze/SourceCode/DaedalusMazeGUI.py in execute_button_clicked(b)
#      56         global AvailableGroups_dropdown
#      57         DisplayBusy()
# ---> 58         getattr( GroupsAction, 'Execute_'+str(AvailableGroups_dropdown.value) )()
#      59         DisplayDone()
#      60
#
# ~/maze/SourceCode/GroupsAction.py in Execute_Interpolator()
#      42         Display( '    Interpolator( ' , PanelDisplayer.WIDGET_Interpolator_model.value,', ' , PanelDisplayer.WIDGET_Interpolator_model_data_file.value,', ' , OrbitSelector_OrbitFilename,', ' , PanelDisplayer.WIDGET_Interpolator_save.value,', ' , PanelDisplayer.WIDGET_Interpolator_VAR.value , ' ) results:')
#      43         Display( '          InterpolatedOrbitCSV: ' + str(Interpolator_InterpolatedOrbitCSV) )
# ---> 44         PlotGlobe( PanelDisplayer.WIDGET_PlotGlobe_DataCSVfilename.value, Interpolator_InterpolatedOrbitCSV, PanelDisplayer.WIDGET_PlotGlobe_GraphTitle.value, PanelDisplayer.WIDGET_PlotGlobe_ColorbarTitle.value, PanelDisplayer.WIDGET_PlotGlobe_ColorscaleName.value )
#      45         Display( '    PlotGlobe( ' , PanelDisplayer.WIDGET_PlotGlobe_DataCSVfilename.value,', ' , Interpolator_InterpolatedOrbitCSV,', ' , PanelDisplayer.WIDGET_PlotGlobe_GraphTitle.value,', ' , PanelDisplayer.WIDGET_PlotGlobe_ColorbarTitle.value,', ' , PanelDisplayer.WIDGET_PlotGlobe_ColorscaleName.value , ' ) results:')
#      46         Display( '          -void-' )
#
# ~/maze/SourceCode/ModulesSourceCode/PlotGlobe/PlotGlobe.py in PlotGlobe(DataCSVfilename, OrbitDataCSVfilename, PlotTitle, ColorbarTitle, ColorscaleName)
#     164         DataMax = np.amax(Data)
#     165     # for the orbit
# --> 166     if len(OrbitDataCSVfilename) > 0:
#     167         orbitCSVreader = csv.reader( open( OrbitDataCSVfilename ) )
#     168         next( orbitCSVreader ) # ignore the csv header
#
# TypeError: object of type 'NoneType' has no len()
