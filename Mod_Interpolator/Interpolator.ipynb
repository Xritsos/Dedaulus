# %%
from Daedalus_Interpolator import *

# ******************************************************************************
# # # Example Call
# Pick model file
model_data_file='tiegcm_s_24900.nc'
# Pick orbit file
orbit_file="DAED_ORB_Evt1_LLA_Per150_Lat80_Srt01Hz_Msc.csv"
save=True
VAR="NE"
Parallel=True
F90=True
Parallel=True
model="TIEGCM"
DaedalusInterpolator(model,model_data_file,orbit_file,save,VAR,Parallel,F90)
# Out:
# Interpolation Starting... 45443 Positions to Interpolate
# Interpolation Finished in  1.4048776626586914 s
# '../../../NAS/Data_Files/ModelsOutput/Interpolation/DAED_ORB_Evt1_LLA_Per150_Lat80_Srt01Hz_Msc_TIEGCM_NE.csv'
